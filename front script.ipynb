# %%
import os
import json

# Folder paths for the two sets of JSON files
folder_path1 = 'C:/Users/shree/OneDrive/Desktop/shrey cap/original files to be modified/front'
folder_path2 = 'C:/Users/shree/OneDrive/Desktop/shrey cap/front/modified final'

# Get lists of JSON file names in each folder
file_names1 = [filename for filename in os.listdir(folder_path1) if filename.endswith('.json')]
file_names2 = [filename for filename in os.listdir(folder_path2) if filename.endswith('.json')]

# Iterate through the files in pairs using zip()
for filename1, filename2 in zip(file_names1, file_names2):
    file_path1 = os.path.join(folder_path1, filename1)
    file_path2 = os.path.join(folder_path2, filename2)
    
    # Load JSON data from the first file
    with open(file_path1, 'r') as file1:
        mainjson = json.load(file1)
    
    # Load JSON data from the second file
    with open(file_path2, 'r') as file2:
        boxjson = json.load(file2)
        
    for item in mainjson['1']:
        if item['text'].strip() == 'Date':
            for subitem in boxjson[0]['annotations']:
                if subitem['label'] == 'date key':
                    item['box'] = subitem['coordinates']
                if subitem['label'] == 'date value':
                    item['linking'][0]['box'] = subitem['coordinates']
        elif item['text'].strip() == 'Branch Name':
            for subitem in boxjson[0]['annotations']:
                if subitem['label'] == 'branch name key':
                    item['box'] = subitem['coordinates']
                if subitem['label'] == 'branch name value':
                    item['linking'][0]['box'] = subitem['coordinates']
        elif item['text'].strip() == 'Branch Code':
            for subitem in boxjson[0]['annotations']:
                if subitem['label'] == 'branch code key':
                    item['box'] = subitem['coordinates']
                if subitem['label'] == 'branch code value':
                    item['linking'][0]['box'] = subitem['coordinates']
        elif item['text'].strip() == 'Customer ID':
            for subitem in boxjson[0]['annotations']:
                if subitem['label'] == 'customer id key':
                    item['box'] = subitem['coordinates']
                if subitem['label'] == 'customer id value':
                    item['linking'][0]['box'] = subitem['coordinates']
        elif item['text'].strip() == 'Application Type':
            for subitem in boxjson[0]['annotations']:
                if subitem['label'] == 'application type key':
                    item['box'] = subitem['coordinates']
                if subitem['label'] == 'new value':
                    item['linking'][0]['linking']['box'] = subitem['coordinates']
                if subitem['label'] == 'new key':
                    item['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'update value':
                    item['linking'][1]['linking']['box'] = subitem['coordinates']
                if subitem['label'] == 'update key':
                    item['linking'][1]['box'] = subitem['coordinates']
        elif item['text'].strip() == 'Account No':
            for subitem in boxjson[0]['annotations']:
                if subitem['label'] == 'account no key':
                    item['box'] = subitem['coordinates']
                if subitem['label'] == 'account no value':
                    item['linking'][0]['box'] = subitem['coordinates']
        elif item['text'].strip() == 'CKYC No':
            for subitem in boxjson[0]['annotations']:
                if subitem['label'] == 'ckyc no key':
                    item['box'] = subitem['coordinates']
                if subitem['label'] == 'ckyc no value':
                    item['linking'][0]['box'] = subitem['coordinates']
        elif item['text'].strip() == 'Account Type':
            for subitem in boxjson[0]['annotations']:
                if subitem['label'] == 'account type key':
                    item['box'] = subitem['coordinates']
                if subitem['label'] == 'normal value':
                    item['linking'][0]['linking']['box'] = subitem['coordinates']
                if subitem['label'] == 'normal key':
                    item['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'small value':
                    item['linking'][1]['linking']['box'] = subitem['coordinates']
                if subitem['label'] == 'small key':
                    item['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'minor value':
                    item['linking'][2]['linking']['box'] = subitem['coordinates']
                if subitem['label'] == 'minor key':
                    item['linking'][2]['box'] = subitem['coordinates']
        elif item['text'].strip() == 'Staff':
            for subitem in boxjson[0]['annotations']:
                if subitem['label'] == 'staff key':
                    item['box'] = subitem['coordinates']
                if subitem['label'] == 'staff value':
                    item['linking'][0]['box'] = subitem['coordinates']
        elif item['text'].strip() == 'PF NO':
            for subitem in boxjson[0]['annotations']:
                if subitem['label'] == 'pf no key':
                    item['box'] = subitem['coordinates']
                if subitem['label'] == 'pf no value1':
                    item['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'pf no value2':
                    item['linking'][1]['box'] = subitem['coordinates']
        elif item['text'].strip() == 'A.Personal Details':
            for subitem in boxjson[0]['annotations']:
                if subitem['label'] == 'personal details key':
                    item['box'] = subitem['coordinates']
                if subitem['label'] == 'name value':
                    item['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'name key':
                    item['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'maiden name value':
                    item['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'maiden name key':
                    item['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'dob value':
                    item['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'dob key':
                    item['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'male key':
                    item['linking'][3]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'male value':
                    item['linking'][3]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'female key':
                    item['linking'][3]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'female value':
                    item['linking'][3]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'third gender key':
                    item['linking'][3]['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'third gender value':
                    item['linking'][3]['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'gender key':
                    item['linking'][3]['box'] = subitem['coordinates']
                    
                if subitem['label'] == 'married key':
                    item['linking'][4]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'married value':
                    item['linking'][4]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'unmarried key':
                    item['linking'][4]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'unarried value':
                    item['linking'][4]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'mothers key':
                    item['linking'][4]['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'mothers value':
                    item['linking'][4]['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'marital status key':
                    item['linking'][4]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'no of dependers key':
                    item['linking'][5]['box'] = subitem['coordinates']
                if subitem['label'] == 'no of dependers value':
                    item['linking'][5]['linking'][0]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'father key':
                    item['linking'][6]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'father value':
                    item['linking'][6]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'mother key':
                    item['linking'][6]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'mother value':
                    item['linking'][6]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'spouse key':
                    item['linking'][6]['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'spouse value':
                    item['linking'][6]['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'name of value':
                    item['linking'][6]['linking'][3]['box'] = subitem['coordinates']
                if subitem['label'] == 'name of key':
                    item['linking'][6]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'name of guardian key':
                    item['linking'][7]['box'] = subitem['coordinates']
                if subitem['label'] == 'name of guardian value':
                    item['linking'][7]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'relationship with guardian key':
                    item['linking'][7]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'relationship with guardian value':
                    item['linking'][7]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                    
                if subitem['label'] == 'indian key':
                    item['linking'][8]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'indian value':
                    item['linking'][8]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'nothers key':
                    item['linking'][8]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'nothers value':
                    item['linking'][8]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'country name key':
                    item['linking'][8]['linking'][1]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'country name value':
                    item['linking'][8]['linking'][1]['linking'][0]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'nationality key':
                    item['linking'][8]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'citizenship key':
                    item['linking'][9]['box'] = subitem['coordinates']
                if subitem['label'] == 'citizenship value':
                    item['linking'][9]['linking'][0]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'state govt key':
                    item['linking'][10]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'state govt value':
                    item['linking'][10]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'central govt key':
                    item['linking'][10]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'central govt value':
                    item['linking'][10]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'psu key':
                    item['linking'][10]['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'psu value':
                    item['linking'][10]['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'defence key':
                    item['linking'][10]['linking'][3]['box'] = subitem['coordinates']
                if subitem['label'] == 'defence value':
                    item['linking'][10]['linking'][3]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'pvt sector key':
                    item['linking'][10]['linking'][4]['box'] = subitem['coordinates']
                if subitem['label'] == 'pvt sector value':
                    item['linking'][10]['linking'][4]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'employee id key':
                    item['linking'][10]['linking'][5]['box'] = subitem['coordinates']
                if subitem['label'] == 'employee id value':
                    item['linking'][10]['linking'][5]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'place of posting key':
                    item['linking'][10]['linking'][6]['box'] = subitem['coordinates']
                if subitem['label'] == 'place of posting value':
                    item['linking'][10]['linking'][6]['linking'][0]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'business key':
                    item['linking'][10]['linking'][7]['box'] = subitem['coordinates']
                if subitem['label'] == 'industrialist key':
                    item['linking'][10]['linking'][7]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'industrialist value':
                    item['linking'][10]['linking'][7]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'trade sect key':
                    item['linking'][10]['linking'][7]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'trade sect value':
                    item['linking'][10]['linking'][7]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'serv sect key':
                    item['linking'][10]['linking'][7]['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'serv sect value':
                    item['linking'][10]['linking'][7]['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'migrant key':
                    item['linking'][10]['linking'][7]['linking'][3]['box'] = subitem['coordinates']
                if subitem['label'] == 'migrant value':
                    item['linking'][10]['linking'][7]['linking'][3]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'contractor key':
                    item['linking'][10]['linking'][7]['linking'][4]['box'] = subitem['coordinates']
                if subitem['label'] == 'contractor value':
                    item['linking'][10]['linking'][7]['linking'][4]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'jeweller key':
                    item['linking'][10]['linking'][7]['linking'][5]['box'] = subitem['coordinates']
                if subitem['label'] == 'jeweller value':
                    item['linking'][10]['linking'][7]['linking'][5]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'pawn shop key':
                    item['linking'][10]['linking'][7]['linking'][6]['box'] = subitem['coordinates']
                if subitem['label'] == 'pawn shop value':
                    item['linking'][10]['linking'][7]['linking'][6]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'importexport key':
                    item['linking'][10]['linking'][7]['linking'][7]['box'] = subitem['coordinates']
                if subitem['label'] == 'importexport value':
                    item['linking'][10]['linking'][7]['linking'][7]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'self employed key':
                    item['linking'][10]['linking'][7]['linking'][8]['box'] = subitem['coordinates']
                if subitem['label'] == 'self employed value':
                    item['linking'][10]['linking'][7]['linking'][8]['linking'][0]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'others11 key':
                    item['linking'][10]['linking'][8]['box'] = subitem['coordinates']
                if subitem['label'] == 'mdeical prof key':
                    item['linking'][10]['linking'][8]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'mdeical prof value':
                    item['linking'][10]['linking'][8]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'legal prof key':
                    item['linking'][10]['linking'][8]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'legal prof value':
                    item['linking'][10]['linking'][8]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'ca key':
                    item['linking'][10]['linking'][8]['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'ca value':
                    item['linking'][10]['linking'][8]['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'eng key':
                    item['linking'][10]['linking'][8]['linking'][3]['box'] = subitem['coordinates']
                if subitem['label'] == 'eng value':
                    item['linking'][10]['linking'][8]['linking'][3]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'retired key':
                    item['linking'][10]['linking'][8]['linking'][4]['box'] = subitem['coordinates']
                if subitem['label'] == 'retired value':
                    item['linking'][10]['linking'][8]['linking'][4]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'journalist key':
                    item['linking'][10]['linking'][8]['linking'][5]['box'] = subitem['coordinates']
                if subitem['label'] == 'journalist value':
                    item['linking'][10]['linking'][8]['linking'][5]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'housewife key':
                    item['linking'][10]['linking'][8]['linking'][6]['box'] = subitem['coordinates']
                if subitem['label'] == 'housewife value':
                    item['linking'][10]['linking'][8]['linking'][6]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'student key':
                    item['linking'][10]['linking'][8]['linking'][7]['box'] = subitem['coordinates']
                if subitem['label'] == 'student value':
                    item['linking'][10]['linking'][8]['linking'][7]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'share key':
                    item['linking'][10]['linking'][8]['linking'][8]['box'] = subitem['coordinates']
                if subitem['label'] == 'share value':
                    item['linking'][10]['linking'][8]['linking'][8]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'oth key':
                    item['linking'][10]['linking'][8]['linking'][9]['box'] = subitem['coordinates']
                if subitem['label'] == 'oth value':
                    item['linking'][10]['linking'][8]['linking'][9]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'agriculture11 key':
                    item['linking'][10]['linking'][8]['linking'][10]['box'] = subitem['coordinates']
                if subitem['label'] == 'agriculture11 value':
                    item['linking'][10]['linking'][8]['linking'][10]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'political key':
                    item['linking'][10]['linking'][8]['linking'][11]['box'] = subitem['coordinates']
                if subitem['label'] == 'political value':
                    item['linking'][10]['linking'][8]['linking'][11]['linking'][0]['box'] = subitem['coordinates']
                    
                if subitem['label'] == 'not cate key':
                    item['linking'][10]['linking'][9]['box'] = subitem['coordinates']
                if subitem['label'] == 'not cate value':
                    item['linking'][10]['linking'][9]['linking'][0]['box'] = subitem['coordinates']
                        
                if subitem['label'] == 'occupation type key':
                    item['linking'][10]['box'] = subitem['coordinates']
                    
                if subitem['label'] == 'org name key':
                    item['linking'][11]['box'] = subitem['coordinates']
                if subitem['label'] == 'org name value':
                    item['linking'][11]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'designation key':
                    item['linking'][11]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'designation value':
                    item['linking'][11]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'nature key':
                    item['linking'][11]['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'nature value':
                    item['linking'][11]['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'annual income key':
                    item['linking'][12]['box'] = subitem['coordinates']
                if subitem['label'] == 'annual income value':
                    item['linking'][12]['linking'][0]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'net worth key':
                    item['linking'][13]['box'] = subitem['coordinates']
                if subitem['label'] == 'net worth value':
                    item['linking'][13]['linking'][0]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'salary key':
                    item['linking'][14]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'salary value':
                    item['linking'][14]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'business income key':
                    item['linking'][14]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'business income value':
                    item['linking'][14]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'agriculture15 key':
                    item['linking'][14]['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'agriculture15 value':
                    item['linking'][14]['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'investment key':
                    item['linking'][14]['linking'][3]['box'] = subitem['coordinates']
                if subitem['label'] == 'investment value':
                    item['linking'][14]['linking'][3]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'pension key':
                    item['linking'][14]['linking'][4]['box'] = subitem['coordinates']
                if subitem['label'] == 'pension value':
                    item['linking'][14]['linking'][4]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'others15 key':
                    item['linking'][14]['linking'][5]['box'] = subitem['coordinates']
                if subitem['label'] == 'others15 value1':
                    item['linking'][14]['linking'][5]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'others15 value2':
                    item['linking'][14]['linking'][5]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'source key':
                    item['linking'][14]['box'] = subitem['coordinates']
                    
                if subitem['label'] == 'hindu key':
                    item['linking'][15]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'hindu value':
                    item['linking'][15]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'muslim key':
                    item['linking'][15]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'muslim value':
                    item['linking'][15]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'christian key':
                    item['linking'][15]['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'christian value':
                    item['linking'][15]['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'sikh key':
                    item['linking'][15]['linking'][3]['box'] = subitem['coordinates']
                if subitem['label'] == 'sikh value':
                    item['linking'][15]['linking'][3]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'others16 key':
                    item['linking'][15]['linking'][4]['box'] = subitem['coordinates']
                if subitem['label'] == 'others16 value1':
                    item['linking'][15]['linking'][4]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'others16 value2':
                    item['linking'][15]['linking'][4]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'religion key':
                    item['linking'][15]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'general key':
                    item['linking'][16]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'general value':
                    item['linking'][16]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'obc key':
                    item['linking'][16]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'obc value':
                    item['linking'][16]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'sc key':
                    item['linking'][16]['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'sc value':
                    item['linking'][16]['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'st key':
                    item['linking'][16]['linking'][3]['box'] = subitem['coordinates']
                if subitem['label'] == 'st value':
                    item['linking'][16]['linking'][3]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'category key':
                    item['linking'][16]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'pyes key':
                    item['linking'][17]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'pyes value':
                    item['linking'][17]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'pno key':
                    item['linking'][17]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'pno value':
                    item['linking'][17]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'ifyes key':
                    item['linking'][17]['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'visual key':
                    item['linking'][17]['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'visual value':
                    item['linking'][17]['linking'][2]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'different key':
                    item['linking'][17]['linking'][2]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'different value':
                    item['linking'][17]['linking'][2]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'person key':
                    item['linking'][17]['box'] = subitem['coordinates']
                    
                if subitem['label'] == 'upto9 key':
                    item['linking'][18]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'upto9 value':
                    item['linking'][18]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == '10 key':
                    item['linking'][18]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == '10 value':
                    item['linking'][18]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'graduate key':
                    item['linking'][18]['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'graduate value':
                    item['linking'][18]['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'post key':
                    item['linking'][18]['linking'][3]['box'] = subitem['coordinates']
                if subitem['label'] == 'post value':
                    item['linking'][18]['linking'][3]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'med key':
                    item['linking'][18]['linking'][4]['box'] = subitem['coordinates']
                if subitem['label'] == 'med value':
                    item['linking'][18]['linking'][4]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'eng grad key':
                    item['linking'][18]['linking'][5]['box'] = subitem['coordinates']
                if subitem['label'] == 'eng grad value':
                    item['linking'][18]['linking'][5]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'law key':
                    item['linking'][18]['linking'][6]['box'] = subitem['coordinates']
                if subitem['label'] == 'law value':
                    item['linking'][18]['linking'][6]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'ca19 key':
                    item['linking'][18]['linking'][7]['box'] = subitem['coordinates']
                if subitem['label'] == 'ca19 value':
                    item['linking'][18]['linking'][7]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'comp degree key':
                    item['linking'][18]['linking'][8]['box'] = subitem['coordinates']
                if subitem['label'] == 'comp degree value':
                    item['linking'][18]['linking'][8]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'diploma key':
                    item['linking'][18]['linking'][9]['box'] = subitem['coordinates']
                if subitem['label'] == 'diploma value':
                    item['linking'][18]['linking'][9]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'illiterate key':
                    item['linking'][18]['linking'][10]['box'] = subitem['coordinates']
                if subitem['label'] == 'illiterate value1':
                    item['linking'][18]['linking'][10]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'illiterate value2':
                    item['linking'][18]['linking'][10]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'education key':
                    item['linking'][18]['box'] = subitem['coordinates']
                    
                if subitem['label'] == 'politically exposed key':
                    item['linking'][19]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'politically exposed value':
                    item['linking'][19]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'related key':
                    item['linking'][19]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'related value':
                    item['linking'][19]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'none key':
                    item['linking'][19]['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'none value':
                    item['linking'][19]['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'please tick key':
                    item['linking'][19]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'taxyes key':
                    item['linking'][20]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'taxyes value':
                    item['linking'][20]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'taxno key':
                    item['linking'][20]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'taxno value':
                    item['linking'][20]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'tax key':
                    item['linking'][20]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'pan key':
                    item['linking'][21]['box'] = subitem['coordinates']
                if subitem['label'] == 'pan value':
                    item['linking'][21]['linking'][0]['box'] = subitem['coordinates']
        elif item['text'].strip() == 'Contact Details':
            for subitem in boxjson[0]['annotations']:
                if subitem['label'] == 'contact details key':
                    item['box'] = subitem['coordinates']
                if subitem['label'] == 'mobileno key':
                    item['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'mobileno value1':
                    item['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'mobileno value2':
                    item['linking'][0]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'email key':
                    item['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'email value':
                    item['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'std key':
                    item['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'std value':
                    item['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'tel key':
                    item['linking'][3]['box'] = subitem['coordinates']
                if subitem['label'] == 'tel value':
                    item['linking'][3]['linking'][0]['box'] = subitem['coordinates']
 
    
  
    with open(file_path1, 'w') as file1:
        json.dump(mainjson, file1, indent=4)  # Optional: specify indentation for readability
    
#     with open(file_path2, 'w') as file2:
#         json.dump(data2, file2, indent=4)  # Optional: specify indentation for readability

# %%
# Assuming boxjson contains your JSON data
boxjson = [
    {
        "image": "289_front.jpg",
        "verified": False,
        "annotations": [
            {
                "label": "date key",
                "coordinates": {"x": 1191.5, "y": 292.9701492537314, "width": 79.0, "height": 36.0}
            }
            # ... other annotations
        ]
    }
    # ... other images
]

# Extract coordinates dictionary
coordinates_dict = list(boxjson[0]['annotations'][0]['coordinates'])

# Create a list of dictionaries with labels and values
# coordinates_list = [
#     {"x": coordinates_dict['x']},
#     {"y": coordinates_dict['y']},
#     {"width": coordinates_dict['width']},
#     {"height": coordinates_dict['height']}
# ]

# Print the list
print(coordinates_dict)
# Out:
# ['x', 'y', 'width', 'height']
