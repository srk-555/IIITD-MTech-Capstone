# %%
import os
import json

# Folder paths for the two sets of JSON files
folder_path1 = 'C:/Users/shree/OneDrive/Desktop/shrey cap/original files to be modified/back'
folder_path2 = 'C:/Users/shree/OneDrive/Desktop/shrey cap/back/final back'

# Get lists of JSON file names in each folder
file_names1 = [filename for filename in os.listdir(folder_path1) if filename.endswith('.json')]
file_names2 = [filename for filename in os.listdir(folder_path2) if filename.endswith('.json')]

# Iterate through the files in pairs using zip()
for filename1, filename2 in zip(file_names1, file_names2):
    file_path1 = os.path.join(folder_path1, filename1)
    file_path2 = os.path.join(folder_path2, filename2)
    
    # Load JSON data from the first file
    with open(file_path1, 'r') as file1:
        mainjson = json.load(file1)
    
    # Load JSON data from the second file
    with open(file_path2, 'r') as file2:
        boxjson = json.load(file2)
        
    for item in mainjson['2']:
        if item['text'].strip() == 'C. PROOF OF IDENTITY':
            for subitem in boxjson[0]['annotations']:
                if subitem['label'] == 'proof of identity key':
                    item['box'] = subitem['coordinates']
                if subitem['label'] == 'passport key':
                    item['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'passport value':
                    item['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'voter key':
                    item['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'voter value':
                    item['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'driving key':
                    item['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'driving value':
                    item['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'aadhar key':
                    item['linking'][3]['box'] = subitem['coordinates']
                if subitem['label'] == 'aadhar value':
                    item['linking'][3]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'ekyc key':
                    item['linking'][4]['box'] = subitem['coordinates']
                if subitem['label'] == 'ekyc value':
                    item['linking'][4]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'offline key':
                    item['linking'][5]['box'] = subitem['coordinates']
                if subitem['label'] == 'offline value':
                    item['linking'][5]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'enrega key':
                    item['linking'][6]['box'] = subitem['coordinates']
                if subitem['label'] == 'enrega value':
                    item['linking'][6]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'fletter key':
                    item['linking'][7]['box'] = subitem['coordinates']
                if subitem['label'] == 'fletter value':
                    item['linking'][7]['linking'][0]['box'] = subitem['coordinates']
                    
                if subitem['label'] == 'whether key':
                    item['linking'][8]['box'] = subitem['coordinates']
                if subitem['label'] == 'wyes key':
                    item['linking'][8]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'wyes value':
                    item['linking'][8]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'wno key':
                    item['linking'][8]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'wno value':
                    item['linking'][8]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'docno key':
                    item['linking'][9]['box'] = subitem['coordinates']
                if subitem['label'] == 'docno value':
                    item['linking'][9]['linking'][0]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'issuedby key':
                    item['linking'][10]['box'] = subitem['coordinates']
                if subitem['label'] == 'issuedby value':
                    item['linking'][10]['linking'][0]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'issuedate key':
                    item['linking'][11]['box'] = subitem['coordinates']
                if subitem['label'] == 'issuedate value':
                    item['linking'][11]['linking'][0]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'proofexpiry key':
                    item['linking'][12]['box'] = subitem['coordinates']
                if subitem['label'] == 'proofexpiry value':
                    item['linking'][12]['linking'][0]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'foreignnationals key':
                    item['linking'][13]['box'] = subitem['coordinates']
                if subitem['label'] == 'visa key':
                    item['linking'][13]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'visa value':
                    item['linking'][13]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'visaissuedby key':
                    item['linking'][13]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'visaissuedby value':
                    item['linking'][13]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'visaissuedate key':
                    item['linking'][13]['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'visaissuedate value':
                    item['linking'][13]['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'visaexpiry key':
                    item['linking'][13]['linking'][3]['box'] = subitem['coordinates']
                if subitem['label'] == 'visaexpiry value':
                    item['linking'][13]['linking'][3]['linking'][0]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'addressdetails key':
                    item['linking'][14]['box'] = subitem['coordinates']
                if subitem['label'] == 'dcurrent key':
                    item['linking'][14]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'dcurrent value':
                    item['linking'][14]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'doverseas key':
                    item['linking'][14]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'doverseas value':
                    item['linking'][14]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'addresstype key':
                    item['linking'][14]['linking'][2]['box'] = subitem['coordinates']          
                if subitem['label'] == 'resident/business key':
                    item['linking'][14]['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'resident/business value':
                    item['linking'][14]['linking'][2]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'residential key':
                    item['linking'][14]['linking'][2]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'residential value':
                    item['linking'][14]['linking'][2]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'business key':
                    item['linking'][14]['linking'][2]['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'business value':
                    item['linking'][14]['linking'][2]['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'registeredoffice key':
                    item['linking'][14]['linking'][2]['linking'][3]['box'] = subitem['coordinates']
                if subitem['label'] == 'registeredoffice value':
                    item['linking'][14]['linking'][2]['linking'][3]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'unspecified key':
                    item['linking'][14]['linking'][2]['linking'][4]['box'] = subitem['coordinates']
                if subitem['label'] == 'unspecified value':
                    item['linking'][14]['linking'][2]['linking'][4]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'address key':
                    item['linking'][14]['linking'][3]['box'] = subitem['coordinates']   
                if subitem['label'] == 'address value':
                    item['linking'][14]['linking'][3]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'city key':
                    item['linking'][14]['linking'][4]['box'] = subitem['coordinates']   
                if subitem['label'] == 'city value':
                    item['linking'][14]['linking'][4]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'district key':
                    item['linking'][14]['linking'][5]['box'] = subitem['coordinates']   
                if subitem['label'] == 'district value':
                    item['linking'][14]['linking'][5]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'state key':
                    item['linking'][14]['linking'][6]['box'] = subitem['coordinates']   
                if subitem['label'] == 'state value':
                    item['linking'][14]['linking'][6]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'pin key':
                    item['linking'][14]['linking'][7]['box'] = subitem['coordinates']   
                if subitem['label'] == 'pin value':
                    item['linking'][14]['linking'][7]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'country name key':
                    item['linking'][14]['linking'][8]['box'] = subitem['coordinates']   
                if subitem['label'] == 'country name value':
                    item['linking'][14]['linking'][8]['linking'][0]['box'] = subitem['coordinates']
            
        elif item['text'].strip() == 'E.Address Details':
            for subitem in boxjson[0]['annotations']:
                if subitem['label'] == 'eaddressdetails key':
                    item['box'] = subitem['coordinates']
                if subitem['label'] == 'ecorrespondence key':
                    item['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'ecorrespondence value':
                    item['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'esame key':
                    item['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'esame value':
                    item['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                
                if subitem['label'] == 'eaddresstype key':
                    item['linking'][2]['box'] = subitem['coordinates']          
                if subitem['label'] == 'eresident/business key':
                    item['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'eresident/business value':
                    item['linking'][2]['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'eresidential key':
                    item['linking'][2]['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'eresidential value':
                    item['linking'][2]['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'ebusiness key':
                    item['linking'][2]['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'ebusiness value':
                    item['linking'][2]['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'eregisteredoffice key':
                    item['linking'][2]['linking'][3]['box'] = subitem['coordinates']
                if subitem['label'] == 'eregisteredoffice value':
                    item['linking'][2]['linking'][3]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'eunspecified key':
                    item['linking'][2]['linking'][4]['box'] = subitem['coordinates']
                if subitem['label'] == 'eunspecified value':
                    item['linking'][2]['linking'][4]['linking'][0]['box'] = subitem['coordinates']
                    
                    
                if subitem['label'] == 'eaddress key':
                    item['linking'][3]['box'] = subitem['coordinates']   
                if subitem['label'] == 'eaddress value':
                    item['linking'][3]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'ecity key':
                    item['linking'][4]['box'] = subitem['coordinates']   
                if subitem['label'] == 'ecity value':
                    item['linking'][4]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'edistrict key':
                    item['linking'][5]['box'] = subitem['coordinates']   
                if subitem['label'] == 'edistrict value':
                    item['linking'][5]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'estate key':
                    item['linking'][6]['box'] = subitem['coordinates']   
                if subitem['label'] == 'estate value':
                    item['linking'][6]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'epin key':
                    item['linking'][7]['box'] = subitem['coordinates']   
                if subitem['label'] == 'epin value':
                    item['linking'][7]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'ecountry name key':
                    item['linking'][8]['box'] = subitem['coordinates']   
                if subitem['label'] == 'ecountry name value':
                    item['linking'][8]['linking'][0]['box'] = subitem['coordinates']
             
        elif item['text'].strip() == 'F if the Ofically valid document(OVD) thus not contain current address-please provide any of the document below.(Not more than 2 months old)':
            for subitem in boxjson[0]['annotations']:
                if subitem['label'] == 'fifvalid key':
                    item['box'] = subitem['coordinates']
                if subitem['label'] == 'utility key':
                    item['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'utility value':
                    item['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'ppo key':
                    item['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'ppo value':
                    item['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'property key':
                    item['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'property value':
                    item['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'letter key':
                    item['linking'][3]['box'] = subitem['coordinates']
                if subitem['label'] == 'letter value':
                    item['linking'][3]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'selfdeclaration key':
                    item['linking'][4]['box'] = subitem['coordinates']
                if subitem['label'] == 'selfdeclaration value':
                    item['linking'][4]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'fdocno key':
                    item['linking'][5]['box'] = subitem['coordinates']
                if subitem['label'] == 'fdocno value':
                    item['linking'][5]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'fdate key':
                    item['linking'][6]['box'] = subitem['coordinates']
                if subitem['label'] == 'fdate value':
                    item['linking'][6]['linking'][0]['box'] = subitem['coordinates']
        
        elif item['text'].strip() == 'G DECLARATON CUM UNDERTAKING CUM SELF-CERTIFICATION':
            for subitem in boxjson[0]['annotations']:
                if subitem['label'] == 'gdeclare key':
                    item['box'] = subitem['coordinates']
                if subitem['label'] == 'gyes key':
                    item['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'gyes value':
                    item['linking'][0]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'gno key':
                    item['linking'][1]['box'] = subitem['coordinates']
                if subitem['label'] == 'gno value':
                    item['linking'][1]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'photo key':
                    item['linking'][2]['box'] = subitem['coordinates']
                if subitem['label'] == 'photo value':
                    item['linking'][2]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'gekyc key':
                    item['linking'][3]['box'] = subitem['coordinates']
                if subitem['label'] == 'gekyc value':
                    item['linking'][3]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'sign key':
                    item['linking'][4]['box'] = subitem['coordinates']
                if subitem['label'] == 'sign value':
                    item['linking'][4]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'place key':
                    item['linking'][5]['box'] = subitem['coordinates']
                if subitem['label'] == 'place value':
                    item['linking'][5]['linking'][0]['box'] = subitem['coordinates']
                if subitem['label'] == 'date key':
                    item['linking'][6]['box'] = subitem['coordinates']
                if subitem['label'] == 'date value':
                    item['linking'][6]['linking'][0]['box'] = subitem['coordinates']

    with open(file_path1, 'w') as file1:
        json.dump(mainjson, file1, indent=4)  # Optional: specify indentation for readability
    
#     with open(file_path2, 'w') as file2:
#         json.dump(data2, file2, indent=4)  # Optional: specify indentation for readability
